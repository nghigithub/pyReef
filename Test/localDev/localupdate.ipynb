# %% [markdown]
# # Build local directory libraries

# %%
# !cd /workspace/volume/pyReef/pyReef/libUtils/; make clobber
# Out:
# for i in WaveComp ; do   \
#     	( cd $i ; make dust) ;       \
# 	done
# make[1]: Entering directory `/workspace/volume/pyReef/pyReef/libUtils/WaveComp'
# rm -f /workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc/*.o /workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc/*.mod /workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc/*.original
# rm -f /workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc/*~ /workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc/*_genmod*
# rm -fv *.bak *~ *.o *.mod *.original *_genmod*
# removed 'SimWaves.o'
# removed 'WaveClass.o'
# make[1]: Leaving directory `/workspace/volume/pyReef/pyReef/libUtils/WaveComp'
# rm -fv *~ *.bak *.o *.mod *.original
# for i in WaveComp ; do   \
#     	( cd $i ; make clobber) ;   \
# 	done
# make[1]: Entering directory `/workspace/volume/pyReef/pyReef/libUtils/WaveComp'
# rm -f /workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc/*.o /workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc/*.mod /workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc/*.original
# rm -f /workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc/*~ /workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc/*_genmod*
# rm -fv *.bak *~ *.o *.mod *.original *_genmod*
# rm -rfv /workspace/volume/pyReef/pyReef/libUtils/WaveComp/build
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/lib/libWaveParam.so'
# removed directory: '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/lib'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/classdata.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/couple.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/m_bndspec.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/m_constants.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/m_diffr.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/m_fileio.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/m_genarr.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/m_obsta.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/m_parall.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/m_snl4.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/m_wcap.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/m_xnldata.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/miscdata.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/mpidata.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/ocpcomm1.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/ocpcomm2.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/ocpcomm3.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/ocpcomm4.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/outp_data.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/serv_xnl4v5.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/simwaves.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/swan_coupler_export.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/swan_coupler_functions.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/swan_coupler_parallel.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/swancompdata.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/swangriddata.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/swangridobjects.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/swcomm1.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/swcomm2.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/swcomm3.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/swcomm4.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/timecomm.mod'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules/wavegrid.mod'
# removed directory: '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/m_constants.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/m_fileio.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/mod_xnl4v5.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/ocpcre.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/ocpids.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/ocpmix.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/serv_xnl4v5.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SimWaves.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanBndStruc.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanBpntlist.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanCheckGrid.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swancom1.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swancom2.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swancom3.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swancom4.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swancom5.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanCompdata.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanCompUnstruc.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanComputeForce.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanConvAccur.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanConvStopc.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanCoupler.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanCreateEdges.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanCrossObstacle.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanDiffPar.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanDispParm.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanFindObstacles.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanFindPoint.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanGridCell.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanGriddata.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanGridFace.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanGridobjects.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanGridTopology.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanGridVert.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanGSECorr.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanInitCompGrid.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanInterpolateAc.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanInterpolateOutput.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanInterpolatePoint.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanIntgratSpc.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanMaxOverNodes.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanMinOverNodes.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swanout1.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swanout2.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swanparll.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanPointinMesh.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swanpre1.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swanpre2.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanPrepComp.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanPrintGridInfo.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanPropvelS.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanPropvelX.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanpyReef.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanReadADCGrid.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanReadEasymeshGrid.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanReadfort18.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanReadGrid.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanReadTriangleGrid.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swanser.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanSumOverNodes.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanSweepSel.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanThreadBounds.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanTranspAc.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanTranspX.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/SwanVertlist.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swmod1.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/swmod2.o'
# removed '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/WaveClass.o'
# removed directory: '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects'
# removed directory: '/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build'
# make[1]: Leaving directory `/workspace/volume/pyReef/pyReef/libUtils/WaveComp'
# rm -rfv /workspace/volume/pyReef/pyReef/libUtils/WaveComp/build *~ *.bak *.o *.mod *.original *.so
# removed 'simswan.so'

# %%
# !cd /workspace/volume/pyReef/pyReef/libUtils/; make dist
# Out:
# *************************************************
# Ocean Plugin Makefile
# *************************************************
#
# for i in WaveComp ; do   \
#     	  ( cd $i ; make dist) ;       \
# 	done
# make[1]: Entering directory `/workspace/volume/pyReef/pyReef/libUtils/WaveComp'
# mpif90 -O3 -funroll-loops --param max-unroll-times=2 -cpp -ffree-form -ftree-vectorize -ffast-math -lstdc++ -ffree-line-length-none -shared -fPIC -I/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules -c WaveClass.f90 -o WaveClass.o
# cp *.o /workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects
# for f in *.mod ; do   \
# 			if [ -f $f ]; then \
# 				mv $f /workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules;       \
# 		fi; 		\
# 	done
#
# *************************************************
# Build modules and library for Ocean Waves
#
# *************************************************
# for i in /workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc ; do   \
#     	( cd $i ; make dist) ;       \
# 	done
# make[2]: Entering directory `/workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc'
# make swan
# make[3]: Entering directory `/workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc'
# mpif90 SwanCoupler.f90 -c -O3 -funroll-loops --param max-unroll-times=2 -cpp -ffree-form -ftree-vectorize -ffast-math -lstdc++ -ffree-line-length-none -shared -fPIC -I../build/modules
# mpif90 SwanpyReef.f -c -O3 -m64 -w -fno-second-underscore -shared  -fPIC
# make[3]: Leaving directory `/workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc'
# cp *.o ../build/objects
# for f in *.mod ; do   \
#     	if [ -f $f ]; then \
#     		cp $f ../build/modules;       \
# 		fi; 		\
# 	done
# make[2]: Leaving directory `/workspace/volume/pyReef/pyReef/libUtils/WaveComp/SwanSrc'
# make /workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/lib/libWaveParam.so
# make[2]: Entering directory `/workspace/volume/pyReef/pyReef/libUtils/WaveComp'
# mpif90 -O3 -funroll-loops --param max-unroll-times=2 -cpp -ffree-form -ftree-vectorize -ffast-math -lstdc++ -ffree-line-length-none -shared -fPIC -I/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules -c SimWaves.f90 -o SimWaves.o
# cp *.o /workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects
# for f in *.mod ; do   \
#     	if [ -f $f ]; then \
#     		mv $f /workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules;       \
# 		fi; 		\
# 	done
# ar -rcs /workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/lib/libWaveParam.so /workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/objects/*.o
# make[2]: Leaving directory `/workspace/volume/pyReef/pyReef/libUtils/WaveComp'
# make[1]: Leaving directory `/workspace/volume/pyReef/pyReef/libUtils/WaveComp'
# *************************************************
#
# Build Swan binary.
#
# *************************************************
# make libs
# make[1]: Entering directory `/workspace/volume/pyReef/pyReef/libUtils'
# f2py --fcompiler=gfortran --f90exec=mpif90 -I/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules -L/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/lib/ -lWaveParam -c -m simswan simswan.f90
# Unknown vendor: "gfortran"
# running build
# running config_cc
# unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# build_src
# building extension "simswan" sources
# f2py options: []
# f2py:> /tmp/tmpAxvNRr/src.linux-x86_64-2.7/simswanmodule.c
# creating /tmp/tmpAxvNRr/src.linux-x86_64-2.7
# Reading fortran codes...
# 	Reading file 'simswan.f90' (format:free)
# Post-processing...
# 	Block: simswan
# 			Block: simswan
# In: :simswan:simswan.f90:simswan
# get_useparameters: no module miscdata info used by simswan
# In: :simswan:simswan.f90:simswan
# get_useparameters: no module classdata info used by simswan
# In: :simswan:simswan.f90:simswan
# get_useparameters: no module mpidata info used by simswan
# In: :simswan:simswan.f90:simswan
# get_useparameters: no module simwaves info used by simswan
# In: :simswan:simswan.f90:simswan
# get_useparameters: no module wavegrid info used by simswan
# 				Block: run
# In: :simswan:simswan.f90:simswan:run
# get_useparameters: no module miscdata info used by run
# In: :simswan:simswan.f90:simswan:run
# get_useparameters: no module classdata info used by run
# In: :simswan:simswan.f90:simswan:run
# get_useparameters: no module mpidata info used by run
# In: :simswan:simswan.f90:simswan:run
# get_useparameters: no module simwaves info used by run
# In: :simswan:simswan.f90:simswan:run
# get_useparameters: no module wavegrid info used by run
# Post-processing (stage 2)...
# 	Block: simswan
# 		Block: unknown_interface
# 			Block: simswan
# 				Block: run
# Building modules...
# 	Building module "simswan"...
# 		Constructing F90 module support for "simswan"...
# 			Constructing wrapper function "simswan.run"...
# 			  run(comm)
# 	Wrote C/API module "simswan" to file "/tmp/tmpAxvNRr/src.linux-x86_64-2.7/simswanmodule.c"
# 	Fortran 90 wrappers are saved to "/tmp/tmpAxvNRr/src.linux-x86_64-2.7/simswan-f2pywrappers2.f90"
#   adding '/tmp/tmpAxvNRr/src.linux-x86_64-2.7/fortranobject.c' to sources.
#   adding '/tmp/tmpAxvNRr/src.linux-x86_64-2.7' to include_dirs.
# copying /usr/local/lib/python2.7/dist-packages/numpy/f2py/src/fortranobject.c -> /tmp/tmpAxvNRr/src.linux-x86_64-2.7
# copying /usr/local/lib/python2.7/dist-packages/numpy/f2py/src/fortranobject.h -> /tmp/tmpAxvNRr/src.linux-x86_64-2.7
#   adding '/tmp/tmpAxvNRr/src.linux-x86_64-2.7/simswan-f2pywrappers2.f90' to sources.
# build_src: building npy-pkg config files
# running build_ext
# customize UnixCCompiler
# customize UnixCCompiler using build_ext
# customize Gnu95FCompiler
# Found executable /usr/bin/mpif90
# Found executable /usr/bin/gfortran
# customize Gnu95FCompiler using build_ext
# building 'simswan' extension
# compiling C sources
# C compiler: x86_64-linux-gnu-gcc -pthread -fno-strict-aliasing -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -fPIC
#
# creating /tmp/tmpAxvNRr/tmp
# creating /tmp/tmpAxvNRr/tmp/tmpAxvNRr
# creating /tmp/tmpAxvNRr/tmp/tmpAxvNRr/src.linux-x86_64-2.7
# compile options: '-I/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules -I/tmp/tmpAxvNRr/src.linux-x86_64-2.7 -I/usr/local/lib/python2.7/dist-packages/numpy/core/include -I/usr/include/python2.7 -c'
# x86_64-linux-gnu-gcc: /tmp/tmpAxvNRr/src.linux-x86_64-2.7/simswanmodule.c
# In file included from /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1777:0,
#                  from /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/ndarrayobject.h:18,
#                  from /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from /tmp/tmpAxvNRr/src.linux-x86_64-2.7/fortranobject.h:13,
#                  from /tmp/tmpAxvNRr/src.linux-x86_64-2.7/simswanmodule.c:18:
# /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: #warning "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it by " \
#   ^
# x86_64-linux-gnu-gcc: /tmp/tmpAxvNRr/src.linux-x86_64-2.7/fortranobject.c
# In file included from /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1777:0,
#                  from /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/ndarrayobject.h:18,
#                  from /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from /tmp/tmpAxvNRr/src.linux-x86_64-2.7/fortranobject.h:13,
#                  from /tmp/tmpAxvNRr/src.linux-x86_64-2.7/fortranobject.c:2:
# /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: #warning "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it by " \
#   ^
# compiling Fortran 90 module sources
# Fortran f77 compiler: /usr/bin/mpif90 -Wall -g -ffixed-form -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran f90 compiler: mpif90 -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran fix compiler: mpif90 -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# compile options: '-I/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules -I/tmp/tmpAxvNRr/src.linux-x86_64-2.7 -I/usr/local/lib/python2.7/dist-packages/numpy/core/include -I/usr/include/python2.7 -c'
# extra options: '-J/tmp/tmpAxvNRr/ -I/tmp/tmpAxvNRr/'
# mpif90:f90: simswan.f90
# compiling Fortran sources
# Fortran f77 compiler: /usr/bin/mpif90 -Wall -g -ffixed-form -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran f90 compiler: mpif90 -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran fix compiler: mpif90 -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# compile options: '-I/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/modules -I/tmp/tmpAxvNRr/src.linux-x86_64-2.7 -I/usr/local/lib/python2.7/dist-packages/numpy/core/include -I/usr/include/python2.7 -c'
# extra options: '-J/tmp/tmpAxvNRr/ -I/tmp/tmpAxvNRr/'
# mpif90:f90: /tmp/tmpAxvNRr/src.linux-x86_64-2.7/simswan-f2pywrappers2.f90
# /usr/bin/mpif90 -Wall -g -Wall -g -shared /tmp/tmpAxvNRr/tmp/tmpAxvNRr/src.linux-x86_64-2.7/simswanmodule.o /tmp/tmpAxvNRr/tmp/tmpAxvNRr/src.linux-x86_64-2.7/fortranobject.o /tmp/tmpAxvNRr/simswan.o /tmp/tmpAxvNRr/tmp/tmpAxvNRr/src.linux-x86_64-2.7/simswan-f2pywrappers2.o -L/workspace/volume/pyReef/pyReef/libUtils/WaveComp/build/lib/ -lWaveParam -lgfortran -o ./simswan.so
# Removing build directory /tmp/tmpAxvNRr
# make[1]: Leaving directory `/workspace/volume/pyReef/pyReef/libUtils'

# %% [markdown]
# # Install local badlands model on the container

# %%
# !cd /workspace/volume/pyReef/pyReef/libUtils/; pip install -e /workspace/volume/pyReef/
# Out:
# Obtaining file:///workspace/volume/pyReef
# Installing collected packages: pyReef
#   Running setup.py develop for pyReef
# Successfully installed pyReef-0.1

# %%
# !cd /workspace/volume/pyReef/pyReef/; python -m compileall .
# Out:
# Listing . ...
# Listing ./forcing ...
# Compiling ./forcing/forceSim.py ...
# Compiling ./forcing/xmlParser.py ...
# Listing ./libUtils ...
# Listing ./libUtils/WaveComp ...
# Listing ./libUtils/WaveComp/SwanSrc ...
# Listing ./libUtils/WaveComp/build ...
# Listing ./libUtils/WaveComp/build/lib ...
# Listing ./libUtils/WaveComp/build/modules ...
# Listing ./libUtils/WaveComp/build/objects ...
# Compiling ./model.py ...
# Listing ./simulation ...
